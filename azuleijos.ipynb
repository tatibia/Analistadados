# %% [markdown]
# <a href="https://colab.research.google.com/github/tatibia/Analistadados/blob/main/azuleijos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Entrada de dados
comprimento = float(input("Digite o comprimento da cozinha (m): "))
largura = float(input("Digite a largura da cozinha (m): "))
altura = float(input("Digite a altura da cozinha (m): "))

# Área total das 4 paredes
area_paredes = 2 * (comprimento * altura) + 2 * (largura * altura)

# Cada caixa cobre 1.5 m²[cite: 1]
caixas = area_paredes / 1.5

print(f"Área total a ser coberta: {area_paredes:.2f} m²")
print(f"Quantidade de caixas de azulejos necessárias: {caixas:.1f}")
