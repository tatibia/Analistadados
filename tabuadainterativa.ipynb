# %% [markdown]
# <a href="https://colab.research.google.com/github/tatibia/Analistadados/blob/main/tabuadainterativa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero = int(input("Digite um número inteiro para ver a tabuada: "))

print(f"\n--- TABUADA DO {numero} ---")
for i in range(1, 11):
    resultado = numero * i
    print(f"{numero} x {i} = {resultado}")
