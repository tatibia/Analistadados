# %% [markdown]
# <a href="https://colab.research.google.com/github/tatibia/Analistadados/blob/main/positivonegativo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
valor = float(input("Digite um valor: "))

if valor >= 0:
    print("O valor é Positivo.")
else:
    print("O valor é Negativo.")
