# %% [markdown]
# <a href="https://colab.research.google.com/github/tatibia/Analistadados/blob/main/filmes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dados_entrada = []

print("Digite 5 nomes de filmes:")
for i in range(5):
    nome = input(f"Filme {i+1}: ")
    dados_entrada.append(nome)

print("\n" + "-" * 30)

# 1. LISTA
lista_filmes = dados_entrada

# 2. TUPLA
tupla_filmes = tuple(dados_entrada)

# 3. SET (elimina duplicatas)
set_filmes = set(dados_entrada)

# 4. DICIONÁRIO (Chave: Valor)
dicionario_filmes = {}
for i in range(len(dados_entrada)):
    dicionario_filmes[i + 1] = dados_entrada[i]

# Exibição dos resultados
print(f"LISTA (Flexível): {lista_filmes}")
print(f"TUPLA (Fixa): {tupla_filmes}")
print(f"SET (Apenas Únicos): {set_filmes}")
print(f"DICIONÁRIO (Chave: Valor): {dicionario_filmes}")
# Out:
# Digite 5 nomes de filmes:
